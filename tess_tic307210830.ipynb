# %%
from imports import *
# %matplotlib inline
# Out:
# Bad key "xtick.labeltop" on line 358 in
# /Users/ryancloutier/.matplotlib/matplotlibrc.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# get tess data
fname = '/Users/ryancloutier/Research/GAIAMdwarfs/MAST/TESS/TIC307210830/tess2018234235059-s0002-0000000307210830-0121-s_lc.fits'
hdu = fits.open(fname)[1].data
bjd = hdu['TIME']
f = hdu['PDCSAP_FLUX']
ef = hdu['PDCSAP_FLUX_ERR']
ef /= np.nanmedian(f)
f /= np.nanmedian(f)

# %%
plt.errorbar(bjd, f, ef, fmt='k.', elinewidth=.9)
# Out:
# <Container object of 3 artists>
